# %% [markdown]
# # 🏙️ Coder of Delhi — Delhi Area Data Analysis
#
# ## 📌 Project Overview
#
# This project analyzes different areas of Delhi using Python, NumPy, Pandas, and Matplotlib.
#
# The analysis focuses on:
# - Population
# - Population Density
# - Average Income
# - Crime Rate
# - Pollution Index
# - Relationships between these variables
#
# ## 🎯 Objectives
#
# - Understand and clean the dataset
# - Analyze area-wise patterns
# - Identify high and low crime areas
# - Compare income, pollution, and population characteristics
# - Study correlations between important variables
# - Create meaningful visualizations
# - Extract data-driven insights

# %% [markdown]
# ## 📂 Dataset Description
#
# The dataset contains area-wise information for selected locations in Delhi.
#
# ### Features
#
# | Column | Description |
# |---|---|
# | `area` | Name of the Delhi area |
# | `population` | Estimated population of the area |
# | `avg_income` | Average income of the area |
# | `crime_rate` | Crime rate of the area |
# | `pollution_index` | Pollution index of the area |
# | `literacy_rate` | Literacy rate of the area |
# | `area_sq_km` | Geographical area in square kilometers |
# | `population_density` | Population per square kilometer |
#
# ### Derived Features
#
# During the analysis, additional features were created:
# - `income_category`
# - `crime_category`
# - `pollution_category`
# - `crime_rank`
# - `crime_normalized`
# - `pollution_normalized`
# - `population_normalized`

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
local_areas = [
    "Rohini",
    "Pitampura",
    "Shalimar Bagh",
    "Model Town",
    "Civil Lines",
    "Kamla Nagar",
    "Mukherjee Nagar",
    "Karol Bagh",
    "Rajendra Place",
    "Patel Nagar",
    "Connaught Place",
    "Paharganj",
    "Chandni Chowk",
    "Lajpat Nagar",
    "Greater Kailash",
    "Saket",
    "Malviya Nagar",
    "Hauz Khas",
    "Green Park",
    "Vasant Kunj",
    "Dwarka",
    "Janakpuri",
    "Uttam Nagar",
    "Tilak Nagar",
    "Punjabi Bagh",
    "Rajouri Garden",
    "Paschim Vihar",
    "Vikaspuri",
    "Mayur Vihar",
    "Preet Vihar",
    "Laxmi Nagar",
    "Shahdara",
    "Dilshad Garden",
    "Vivek Vihar",
    "Karkardooma",
    "Okhla",
    "Jasola",
    "Kalkaji",
    "Nehru Place",
    "Sangam Vihar"
]

# %%
area_data = np.random.choice(local_areas, size=150, replace=True)

# %%
area_data
# Out:
# array(['Green Park', 'Tilak Nagar', 'Mayur Vihar', 'Tilak Nagar',
#        'Dilshad Garden', 'Lajpat Nagar', 'Karkardooma', 'Kalkaji',
#        'Connaught Place', 'Kamla Nagar', 'Malviya Nagar', 'Vivek Vihar',
#        'Paharganj', 'Green Park', 'Jasola', 'Karkardooma', 'Preet Vihar',
#        'Saket', 'Kamla Nagar', 'Laxmi Nagar', 'Mayur Vihar',
#        'Connaught Place', 'Vivek Vihar', 'Pitampura', 'Rajouri Garden',
#        'Jasola', 'Kamla Nagar', 'Shahdara', 'Dilshad Garden',
#        'Dilshad Garden', 'Paschim Vihar', 'Greater Kailash',
#        'Preet Vihar', 'Dwarka', 'Greater Kailash', 'Janakpuri', 'Rohini',
#        'Vivek Vihar', 'Shahdara', 'Tilak Nagar', 'Kalkaji', 'Hauz Khas',
#        'Jasola', 'Chandni Chowk', 'Rohini', 'Chandni Chowk',
#        'Mukherjee Nagar', 'Rohini', 'Patel Nagar', 'Rajendra Place',
#        'Rajouri Garden', 'Connaught Place', 'Karol Bagh', 'Model Town',
#        'Dwarka', 'Karkardooma', 'Mukherjee Nagar', 'Kamla Nagar',
#        'Greater Kailash', 'Karkardooma', 'Vasant Kunj', 'Pitampura',
#        'Pitampura', 'Rajendra Place', 'Mukherjee Nagar', 'Mayur Vihar',
#        'Laxmi Nagar', 'Connaught Place', 'Green Park', 'Paharganj',
#        'Model Town', 'Jasola', 'Punjabi Bagh', 'Kalkaji',
#        'Mukherjee Nagar', 'Uttam Nagar', 'Chandni Chowk', 'Civil Lines',
#        'Vikaspuri', 'Kamla Nagar', 'Vasant Kunj', 'Dilshad Garden',
#        'Mayur Vihar', 'Vivek Vihar', 'Jasola', 'Punjabi Bagh',
#        'Patel Nagar', 'Kamla Nagar', 'Paschim Vihar', 'Vivek Vihar',
#        'Rajouri Garden', 'Malviya Nagar', 'Vivek Vihar', 'Model Town',
#        'Greater Kailash', 'Tilak Nagar', 'Shalimar Bagh', 'Preet Vihar',
#        'Dilshad Garden', 'Uttam Nagar', 'Mukherjee Nagar', 'Karkardooma',
#        'Green Park', 'Paharganj', 'Hauz Khas', 'Mukherjee Nagar',
#        'Jasola', 'Connaught Place', 'Uttam Nagar', 'Connaught Place',
#        'Model Town', 'Hauz Khas', 'Okhla', 'Kalkaji', 'Green Park',
#        'Janakpuri', 'Jasola', 'Greater Kailash', 'Greater Kailash',
#        'Green Park', 'Punjabi Bagh', 'Rajouri Garden', 'Vivek Vihar',
#        'Kamla Nagar', 'Chandni Chowk', 'Civil Lines', 'Dilshad Garden',
#        'Shahdara', 'Rajendra Place', 'Shahdara', 'Malviya Nagar',
#        'Rajendra Place', 'Civil Lines', 'Mayur Vihar', 'Chandni Chowk',
#        'Green Park', 'Laxmi Nagar', 'Shahdara', 'Patel Nagar',
#        'Vivek Vihar', 'Kalkaji', 'Civil Lines', 'Rohini', 'Dwarka',
#        'Saket', 'Hauz Khas', 'Connaught Place', 'Janakpuri', 'Kalkaji',
#        'Rohini'], dtype='<U15')

# %%
population = np.random.randint(20000,500000,size = 150)

# %%
len(population)
# Out:
# 150

# %%
population[:10]
# Out:
# array([133185, 144991, 236590, 342568, 465837,  24462, 458109, 117240,
#        220872,  83717], dtype=int32)

# %%
avg_income = np.random.randint(20000,200000,size= 150)

# %%
avg_income[:15]
# Out:
# array([160399, 132488, 169649, 169587,  58601, 127512, 178756, 163997,
#         50690, 138490,  41075,  98085,  97661, 144026, 191682],
#       dtype=int32)

# %%
crime_rate = np.random.uniform(5,95,size=150)

# %%
crime_rate[5:15]
# Out:
# array([77.46353698, 38.29107448, 84.41733916, 25.17023084, 62.78977381,
#         5.67929842,  5.95237912, 66.29300786, 40.93791027,  6.34613301])

# %%
literacy_rate = np.random.uniform(70, 99, size=150)

# %%
literacy_rate[0:25]
# Out:
# array([87.26802556, 80.84096793, 80.00314276, 76.117045  , 97.87390504,
#        96.05808508, 91.85897541, 88.90497187, 92.58952391, 78.01107214,
#        75.20067882, 85.88131018, 84.59285326, 89.42788808, 94.6754191 ,
#        96.98799148, 95.5400614 , 94.25686604, 78.58537376, 88.84210917,
#        70.6784789 , 92.24091541, 81.41496515, 76.42992416, 77.47944339])

# %%
len(literacy_rate)
# Out:
# 150

# %%
area_sq_km = np.random.uniform(1, 35, size=150)

# %%
population_density = population / area_sq_km

# %%
population_density[:10]
# Out:
# array([ 49891.36894062,  13489.83846414,  25339.85019056,  27483.16836352,
#        145704.57768581,   5387.70711402,  17500.70937697,   7487.30931463,
#          9506.45591704,   9325.35876071])

# %%
population_index = np.random.uniform(20, 95, size=150)

# %%
df = pd.DataFrame({
    "area": area_data,
    "population":population,
    "avg_income": avg_income,
    "crime_rate": crime_rate,
    "pollution_index": pollution_index,
    "literacy_rate": literacy_rate,
    "area_sq_km": area_sq_km,
    "population_density": population_density
})

# %%
df
# Out:
#                 area  population  avg_income  crime_rate  pollution_index  \
# 0         Green Park      133185      160399   15.480187        75.019486
# 1        Tilak Nagar      144991      132488   13.019700        64.670966
# 2        Mayur Vihar      236590      169649   10.760975        23.322697
# 3        Tilak Nagar      342568      169587   30.969756        30.060974
# 4     Dilshad Garden      465837       58601   30.115848        56.150386
# ..               ...         ...         ...         ...              ...
# 145        Hauz Khas       51809       80832   30.035728        61.498377
# 146  Connaught Place      443495       28534    6.543346        52.778395
# 147        Janakpuri      482119       24147    8.610870        92.120882
# 148          Kalkaji      206836       80922   30.256999        61.537272
# 149           Rohini      230771      155087   26.569081        51.720413
#
#      literacy_rate  area_sq_km  population_density
# 0        87.268026    2.669500        49891.368941
# 1        80.840968   10.748164        13489.838464
# 2        80.003143    9.336677        25339.850191
# 3        76.117045   12.464647        27483.168364
# 4        97.873905    3.197134       145704.577686
# ..             ...         ...                 ...
# 145      90.549259   19.947897         2597.216082
# 146      97.810376    6.773255        65477.376977
# 147      94.440969   28.853966        16708.933753
# 148      89.955147    5.309930        38952.676212
# 149      90.736575   32.284422         7148.060495
#
# [150 rows x 8 columns]

# %%
df.head()
# Out:
#              area  population  avg_income  crime_rate  pollution_index  \
# 0      Green Park      133185      160399   15.480187        75.019486
# 1     Tilak Nagar      144991      132488   13.019700        64.670966
# 2     Mayur Vihar      236590      169649   10.760975        23.322697
# 3     Tilak Nagar      342568      169587   30.969756        30.060974
# 4  Dilshad Garden      465837       58601   30.115848        56.150386
#
#    literacy_rate  area_sq_km  population_density
# 0      87.268026    2.669500        49891.368941
# 1      80.840968   10.748164        13489.838464
# 2      80.003143    9.336677        25339.850191
# 3      76.117045   12.464647        27483.168364
# 4      97.873905    3.197134       145704.577686

# %%
df.tail()
# Out:
#                 area  population  avg_income  crime_rate  pollution_index  \
# 145        Hauz Khas       51809       80832   30.035728        61.498377
# 146  Connaught Place      443495       28534    6.543346        52.778395
# 147        Janakpuri      482119       24147    8.610870        92.120882
# 148          Kalkaji      206836       80922   30.256999        61.537272
# 149           Rohini      230771      155087   26.569081        51.720413
#
#      literacy_rate  area_sq_km  population_density
# 145      90.549259   19.947897         2597.216082
# 146      97.810376    6.773255        65477.376977
# 147      94.440969   28.853966        16708.933753
# 148      89.955147    5.309930        38952.676212
# 149      90.736575   32.284422         7148.060495

# %%
df.shape
# Out:
# (150, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   area                150 non-null    object
#  1   population          150 non-null    int32
#  2   avg_income          150 non-null    int32
#  3   crime_rate          150 non-null    float64
#  4   pollution_index     150 non-null    float64
#  5   literacy_rate       150 non-null    float64
#  6   area_sq_km          150 non-null    float64
#  7   population_density  150 non-null    float64
# dtypes: float64(5), int32(2), object(1)
# memory usage: 8.3+ KB

# %%
df.describe()
# Out:
#           population     avg_income  crime_rate  pollution_index  \
# count     150.000000     150.000000  150.000000       150.000000
# mean   270623.333333  114465.120000   47.935114        56.863266
# std    142183.214914   51195.146755   26.506540        21.576720
# min     24462.000000   21866.000000    5.550085        20.475478
# 25%    144519.500000   75064.250000   25.198020        39.648350
# 50%    273273.500000  117916.000000   47.486866        54.295484
# 75%    387765.250000  158481.000000   72.953679        74.994293
# max    497060.000000  199131.000000   94.903813        94.884380
#
#        literacy_rate  area_sq_km  population_density
# count     150.000000  150.000000          150.000000
# mean       84.607753   16.592455        35196.267108
# std         7.974121   10.329544        48779.669304
# min        70.119746    1.020036          905.266722
# 25%        77.611992    6.907324         7239.063541
# 50%        84.863879   16.608239        16725.533500
# 75%        91.359429   26.231076        35215.349190
# max        98.975020   34.217261       282750.928737

# %%
df.isnull().sum()
# Out:
# area                  0
# population            0
# avg_income            0
# crime_rate            0
# pollution_index       0
# literacy_rate         0
# area_sq_km            0
# population_density    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['area', 'population', 'avg_income', 'crime_rate', 'pollution_index',
#        'literacy_rate', 'area_sq_km', 'population_density'],
#       dtype='object')

# %%
df[["crime_rate", "pollution_index", "literacy_rate", "area_sq_km", "population_density"]] = df[["crime_rate", "pollution_index", "literacy_rate", "area_sq_km", "population_density"]].round(2)

# %%
df.head()
# Out:
#              area  population  avg_income  crime_rate  pollution_index  \
# 0      Green Park      133185      160399       15.48            75.02
# 1     Tilak Nagar      144991      132488       13.02            64.67
# 2     Mayur Vihar      236590      169649       10.76            23.32
# 3     Tilak Nagar      342568      169587       30.97            30.06
# 4  Dilshad Garden      465837       58601       30.12            56.15
#
#    literacy_rate  area_sq_km  population_density
# 0          87.27        2.67            49891.37
# 1          80.84       10.75            13489.84
# 2          80.00        9.34            25339.85
# 3          76.12       12.46            27483.17
# 4          97.87        3.20           145704.58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   area                150 non-null    object
#  1   population          150 non-null    int32
#  2   avg_income          150 non-null    int32
#  3   crime_rate          150 non-null    float64
#  4   pollution_index     150 non-null    float64
#  5   literacy_rate       150 non-null    float64
#  6   area_sq_km          150 non-null    float64
#  7   population_density  150 non-null    float64
# dtypes: float64(5), int32(2), object(1)
# memory usage: 8.3+ KB

# %%
df["area"].value_counts().head()
# Out:
# area
# Vivek Vihar        8
# Green Park         7
# Connaught Place    7
# Jasola             7
# Kamla Nagar        7
# Name: count, dtype: int64

# %%
df.sort_values("population", ascending=False).head(5)
# Out:
#              area  population  avg_income  crime_rate  pollution_index  \
# 127      Shahdara      497060      187770       11.78            78.72
# 84         Jasola      496131       60608       78.82            31.16
# 72   Punjabi Bagh      494595      133189       62.17            72.79
# 54         Dwarka      493574      179542       86.85            49.23
# 119    Green Park      489595      186535       44.87            42.82
#
#      literacy_rate  area_sq_km  population_density
# 127          82.26       20.38            24389.75
# 84           96.53       19.13            25928.39
# 72           79.41       16.57            29843.89
# 54           77.77        6.49            76106.70
# 119          74.20       16.47            29726.76

# %%
df.groupby("area")["population"].mean().head(10)
# Out:
# area
# Chandni Chowk      158046.200000
# Civil Lines        162535.500000
# Connaught Place    215351.428571
# Dilshad Garden     354656.166667
# Dwarka             410917.000000
# Greater Kailash    287164.500000
# Green Park         276742.142857
# Hauz Khas          244451.750000
# Janakpuri          320895.000000
# Jasola             250851.428571
# Name: population, dtype: float64

# %%
df.groupby("area")["population"].mean().sort_values(ascending=False).head(10)
# Out:
# area
# Punjabi Bagh      429778.000000
# Dwarka            410917.000000
# Mayur Vihar       399781.000000
# Paschim Vihar     396060.000000
# Okhla             383897.000000
# Rajouri Garden    377848.750000
# Laxmi Nagar       369056.333333
# Paharganj         362877.333333
# Shalimar Bagh     359488.000000
# Dilshad Garden    354656.166667
# Name: population, dtype: float64

# %%
df.groupby("area")["population"].agg(["mean", "max", "min"]).tail()
# Out:
#                       mean     max     min
# area
# Tilak Nagar  203079.250000  342568   76273
# Uttam Nagar  196004.333333  281453  102785
# Vasant Kunj  216235.500000  357120   75351
# Vikaspuri     54645.000000   54645   54645
# Vivek Vihar  294335.875000  464560   72739

# %%
df.groupby("area").agg({
    "population": "mean",
    "avg_income": "mean",
    "crime_rate": "mean"
}).head(20)
# Out:
#                     population     avg_income  crime_rate
# area
# Chandni Chowk    158046.200000   90853.800000   50.662000
# Civil Lines      162535.500000   79845.500000   26.457500
# Connaught Place  215351.428571   91899.000000   31.354286
# Dilshad Garden   354656.166667   86736.000000   40.556667
# Dwarka           410917.000000  128578.000000   63.696667
# Greater Kailash  287164.500000  122758.333333   69.546667
# Green Park       276742.142857  148046.285714   35.161429
# Hauz Khas        244451.750000   79080.500000   42.822500
# Janakpuri        320895.000000   90437.666667   42.256667
# Jasola           250851.428571  118539.714286   54.410000
# Kalkaji          267657.000000   79079.833333   47.505000
# Kamla Nagar      166050.857143   94437.714286   71.088571
# Karkardooma      336938.000000  148099.200000   38.332000
# Karol Bagh       197199.000000  120952.000000   34.620000
# Lajpat Nagar      24462.000000  127512.000000   77.460000
# Laxmi Nagar      369056.333333  105007.666667   63.766667
# Malviya Nagar    347394.000000   94352.666667   36.590000
# Mayur Vihar      399781.000000  109297.200000   56.338000
# Model Town       258062.000000   67886.250000   39.285000
# Mukherjee Nagar  251587.666667  107631.333333   40.455000

# %%
df["area"].unique()
# Out:
# array(['Green Park', 'Tilak Nagar', 'Mayur Vihar', 'Dilshad Garden',
#        'Lajpat Nagar', 'Karkardooma', 'Kalkaji', 'Connaught Place',
#        'Kamla Nagar', 'Malviya Nagar', 'Vivek Vihar', 'Paharganj',
#        'Jasola', 'Preet Vihar', 'Saket', 'Laxmi Nagar', 'Pitampura',
#        'Rajouri Garden', 'Shahdara', 'Paschim Vihar', 'Greater Kailash',
#        'Dwarka', 'Janakpuri', 'Rohini', 'Hauz Khas', 'Chandni Chowk',
#        'Mukherjee Nagar', 'Patel Nagar', 'Rajendra Place', 'Karol Bagh',
#        'Model Town', 'Vasant Kunj', 'Punjabi Bagh', 'Uttam Nagar',
#        'Civil Lines', 'Vikaspuri', 'Shalimar Bagh', 'Okhla'], dtype=object)

# %%
df[df["population"] > 400000]
# Out:
#                 area  population  avg_income  crime_rate  pollution_index  \
# 4     Dilshad Garden      465837       58601       30.12            56.15
# 6        Karkardooma      458109      178756       38.29            76.73
# 17             Saket      449020      182176       31.99            39.42
# 19       Laxmi Nagar      458088      107962       79.02            90.74
# 20       Mayur Vihar      460381       41255       51.46            74.58
# 28    Dilshad Garden      469047       67935        8.32            32.45
# 30     Paschim Vihar      456928      189868       78.39            62.88
# 31   Greater Kailash      402651       45635       79.27            59.47
# 33            Dwarka      429457       68891       21.13            86.77
# 37       Vivek Vihar      464560       92368       65.51            31.96
# 41         Hauz Khas      470682       60933       18.22            74.91
# 50    Rajouri Garden      469401      192657       84.90            23.50
# 54            Dwarka      493574      179542       86.85            49.23
# 55       Karkardooma      460205      170530       44.53            66.64
# 56   Mukherjee Nagar      448030       67109       70.30            80.13
# 68        Green Park      450913       85306       75.31            68.87
# 69         Paharganj      418046      142562       69.20            59.69
# 72      Punjabi Bagh      494595      133189       62.17            72.79
# 73           Kalkaji      456614       22358        5.59            90.19
# 82       Mayur Vihar      457036       76469       88.58            71.61
# 83       Vivek Vihar      426068      199131       49.45            78.45
# 84            Jasola      496131       60608       78.82            31.16
# 90    Rajouri Garden      461485      133885       52.42            29.84
# 97       Preet Vihar      485334      142469       76.15            48.51
# 100  Mukherjee Nagar      478840      102926       14.82            50.20
# 101      Karkardooma      441857       42959       13.64            84.88
# 113          Kalkaji      433995       21866       75.83            78.74
# 119       Green Park      489595      186535       44.87            42.82
# 120     Punjabi Bagh      455096       24963       77.13            94.88
# 121   Rajouri Garden      481295       87164       14.12            40.91
# 126   Dilshad Garden      472674       80134       40.93            72.74
# 127         Shahdara      497060      187770       11.78            78.72
# 133      Mayur Vihar      458806      184072       74.44            57.70
# 139      Vivek Vihar      418447      111265       47.00            26.10
# 146  Connaught Place      443495       28534        6.54            52.78
# 147        Janakpuri      482119       24147        8.61            92.12
#
#      literacy_rate  area_sq_km  population_density
# 4            97.87        3.20           145704.58
# 6            91.86       26.18            17500.71
# 17           94.26       26.82            16742.13
# 19           88.84       33.20            13797.91
# 20           70.68       30.36            15161.83
# 28           75.09       30.50            15381.01
# 30           83.41        7.58            60298.04
# 31           82.40       24.62            16357.86
# 33           87.65       17.23            24927.72
# 37           86.53        8.56            54247.77
# 41           92.29       30.36            15505.63
# 50           95.66       32.46            14460.70
# 54           77.77        6.49            76106.70
# 55           80.80        2.06           223374.00
# 56           72.34       34.22            13093.68
# 68           73.61       25.57            17634.32
# 69           98.98       18.69            22370.58
# 72           79.41       16.57            29843.89
# 73           98.11       23.77            19213.40
# 82           78.29       27.46            16645.21
# 83           77.58       32.52            13103.60
# 84           96.53       19.13            25928.39
# 90           92.00        6.43            71726.35
# 97           88.55       16.64            29160.16
# 100          74.74       25.58            18718.54
# 101          84.12       27.97            15798.89
# 113          92.43       17.09            25397.19
# 119          74.20       16.47            29726.76
# 120          82.59       14.25            31939.94
# 121          75.54       20.77            23175.82
# 126          90.65        6.05            78119.27
# 127          82.26       20.38            24389.75
# 133          91.96        2.96           154895.75
# 139          75.17       16.78            24942.09
# 146          97.81        6.77            65477.38
# 147          94.44       28.85            16708.93

# %%
df[df["crime_rate"]>85]
# Out:
#                 area  population  avg_income  crime_rate  pollution_index  \
# 25            Jasola      274042      160683       92.29            33.95
# 42            Jasola       75125       87354       85.08            52.38
# 47            Rohini      318479      185492       94.90            52.93
# 48       Patel Nagar      209737       52901       93.82            66.35
# 54            Dwarka      493574      179542       86.85            49.23
# 57       Kamla Nagar       63476      122533       94.85            51.87
# 58   Greater Kailash      388323      157344       90.92            41.42
# 79       Kamla Nagar      314607       53395       94.28            26.07
# 82       Mayur Vihar      457036       76469       88.58            71.61
# 85      Punjabi Bagh      339643       31551       88.12            42.97
# 115        Janakpuri      336164      122143       92.88            53.83
# 118  Greater Kailash      190704      182203       94.00            85.47
#
#      literacy_rate  area_sq_km  population_density
# 25           98.18        9.94            27559.91
# 42           81.97       31.76             2365.29
# 47           98.89        2.38           133779.60
# 48           91.40       25.96             8079.33
# 54           77.77        6.49            76106.70
# 57           74.66       11.84             5361.00
# 58           72.84        1.89           205702.54
# 79           86.59       26.25            11985.38
# 82           78.29       27.46            16645.21
# 85           85.40       11.83            28718.10
# 115          87.60        3.26           103120.58
# 118          93.88        1.47           129440.84

# %%
df[(df["population"]>40000) & (df["crime_rate"]> 70)]
# Out:
#                 area  population  avg_income  crime_rate  pollution_index  \
# 7            Kalkaji      117240      163997       84.42            31.54
# 15       Karkardooma      116391      150450       75.44            36.70
# 19       Laxmi Nagar      458088      107962       79.02            90.74
# 25            Jasola      274042      160683       92.29            33.95
# 30     Paschim Vihar      456928      189868       78.39            62.88
# 31   Greater Kailash      402651       45635       79.27            59.47
# 32       Preet Vihar       85006      181694       71.18            20.59
# 34   Greater Kailash      364782      105101       80.08            45.45
# 36            Rohini      180032      129598       82.30            59.53
# 42            Jasola       75125       87354       85.08            52.38
# 45     Chandni Chowk       40142      145286       75.21            67.66
# 47            Rohini      318479      185492       94.90            52.93
# 48       Patel Nagar      209737       52901       93.82            66.35
# 50    Rajouri Garden      469401      192657       84.90            23.50
# 54            Dwarka      493574      179542       86.85            49.23
# 56   Mukherjee Nagar      448030       67109       70.30            80.13
# 57       Kamla Nagar       63476      122533       94.85            51.87
# 58   Greater Kailash      388323      157344       90.92            41.42
# 68        Green Park      450913       85306       75.31            68.87
# 70        Model Town      358386       22785       84.37            44.58
# 71            Jasola       44948      142411       72.05            53.75
# 74   Mukherjee Nagar       72219       93488       73.26            20.48
# 79       Kamla Nagar      314607       53395       94.28            26.07
# 82       Mayur Vihar      457036       76469       88.58            71.61
# 84            Jasola      496131       60608       78.82            31.16
# 85      Punjabi Bagh      339643       31551       88.12            42.97
# 86       Patel Nagar       60294      117201       83.89            72.17
# 97       Preet Vihar      485334      142469       76.15            48.51
# 98    Dilshad Garden      220782      134143       78.81            38.71
# 104        Hauz Khas       87301       22075       75.92            88.14
# 113          Kalkaji      433995       21866       75.83            78.74
# 115        Janakpuri      336164      122143       92.88            53.83
# 118  Greater Kailash      190704      182203       94.00            85.47
# 120     Punjabi Bagh      455096       24963       77.13            94.88
# 123      Kamla Nagar      183360       54628       82.10            51.88
# 128   Rajendra Place      362490       91563       75.50            89.02
# 133      Mayur Vihar      458806      184072       74.44            57.70
# 140          Kalkaji      141240       85788       74.53            28.53
# 143           Dwarka      309720      137301       83.11            50.84
#
#      literacy_rate  area_sq_km  population_density
# 7            88.90       15.66             7487.31
# 15           96.99       23.99             4851.62
# 19           88.84       33.20            13797.91
# 25           98.18        9.94            27559.91
# 30           83.41        7.58            60298.04
# 31           82.40       24.62            16357.86
# 32           93.26        4.72            18018.37
# 34           70.12        6.20            58867.24
# 36           70.93       29.48             6107.78
# 42           81.97       31.76             2365.29
# 45           96.60        7.39             5433.13
# 47           98.89        2.38           133779.60
# 48           91.40       25.96             8079.33
# 50           95.66       32.46            14460.70
# 54           77.77        6.49            76106.70
# 56           72.34       34.22            13093.68
# 57           74.66       11.84             5361.00
# 58           72.84        1.89           205702.54
# 68           73.61       25.57            17634.32
# 70           86.86        1.27           282750.93
# 71           92.10       16.26             2764.76
# 74           85.70       10.43             6925.34
# 79           86.59       26.25            11985.38
# 82           78.29       27.46            16645.21
# 84           96.53       19.13            25928.39
# 85           85.40       11.83            28718.10
# 86           75.81       14.28             4222.16
# 97           88.55       16.64            29160.16
# 98           97.34       17.01            12976.46
# 104          90.08       19.76             4418.19
# 113          92.43       17.09            25397.19
# 115          87.60        3.26           103120.58
# 118          93.88        1.47           129440.84
# 120          82.59       14.25            31939.94
# 123          91.18        5.37            34138.43
# 128          98.85        3.81            95070.82
# 133          91.96        2.96           154895.75
# 140          98.24        1.02           138465.64
# 143          74.69       32.67             9481.59

# %%
df.groupby("area")[["population", "avg_income", "crime_rate"]].mean()
# Out:
#                     population     avg_income  crime_rate
# area
# Chandni Chowk    158046.200000   90853.800000   50.662000
# Civil Lines      162535.500000   79845.500000   26.457500
# Connaught Place  215351.428571   91899.000000   31.354286
# Dilshad Garden   354656.166667   86736.000000   40.556667
# Dwarka           410917.000000  128578.000000   63.696667
# Greater Kailash  287164.500000  122758.333333   69.546667
# Green Park       276742.142857  148046.285714   35.161429
# Hauz Khas        244451.750000   79080.500000   42.822500
# Janakpuri        320895.000000   90437.666667   42.256667
# Jasola           250851.428571  118539.714286   54.410000
# Kalkaji          267657.000000   79079.833333   47.505000
# Kamla Nagar      166050.857143   94437.714286   71.088571
# Karkardooma      336938.000000  148099.200000   38.332000
# Karol Bagh       197199.000000  120952.000000   34.620000
# Lajpat Nagar      24462.000000  127512.000000   77.460000
# Laxmi Nagar      369056.333333  105007.666667   63.766667
# Malviya Nagar    347394.000000   94352.666667   36.590000
# Mayur Vihar      399781.000000  109297.200000   56.338000
# Model Town       258062.000000   67886.250000   39.285000
# Mukherjee Nagar  251587.666667  107631.333333   40.455000
# Okhla            383897.000000   23685.000000   56.770000
# Paharganj        362877.333333  103235.666667   61.636667
# Paschim Vihar    396060.000000  193901.500000   54.240000
# Patel Nagar      180845.333333  105418.666667   75.996667
# Pitampura        189095.000000  141253.666667   46.720000
# Preet Vihar      271773.666667  145682.000000   59.346667
# Punjabi Bagh     429778.000000   63234.333333   75.806667
# Rajendra Place   246159.250000  126941.000000   51.552500
# Rajouri Garden   377848.750000  140394.000000   47.515000
# Rohini           183164.400000  145177.800000   49.468000
# Saket            306976.500000  155623.000000   46.940000
# Shahdara         291422.600000  150164.400000   18.806000
# Shalimar Bagh    359488.000000  167348.000000   58.800000
# Tilak Nagar      203079.250000  142752.750000   26.735000
# Uttam Nagar      196004.333333  171248.000000   56.156667
# Vasant Kunj      216235.500000  138261.500000   47.700000
# Vikaspuri         54645.000000  107966.000000   32.140000
# Vivek Vihar      294335.875000  111016.750000   43.595000

# %%
df.pivot_table(
    index = "area",
    values = ["population", "crime_rate"],
    aggfunc  = "mean"
)
# Out:
#                  crime_rate     population
# area
# Chandni Chowk     50.662000  158046.200000
# Civil Lines       26.457500  162535.500000
# Connaught Place   31.354286  215351.428571
# Dilshad Garden    40.556667  354656.166667
# Dwarka            63.696667  410917.000000
# Greater Kailash   69.546667  287164.500000
# Green Park        35.161429  276742.142857
# Hauz Khas         42.822500  244451.750000
# Janakpuri         42.256667  320895.000000
# Jasola            54.410000  250851.428571
# Kalkaji           47.505000  267657.000000
# Kamla Nagar       71.088571  166050.857143
# Karkardooma       38.332000  336938.000000
# Karol Bagh        34.620000  197199.000000
# Lajpat Nagar      77.460000   24462.000000
# Laxmi Nagar       63.766667  369056.333333
# Malviya Nagar     36.590000  347394.000000
# Mayur Vihar       56.338000  399781.000000
# Model Town        39.285000  258062.000000
# Mukherjee Nagar   40.455000  251587.666667
# Okhla             56.770000  383897.000000
# Paharganj         61.636667  362877.333333
# Paschim Vihar     54.240000  396060.000000
# Patel Nagar       75.996667  180845.333333
# Pitampura         46.720000  189095.000000
# Preet Vihar       59.346667  271773.666667
# Punjabi Bagh      75.806667  429778.000000
# Rajendra Place    51.552500  246159.250000
# Rajouri Garden    47.515000  377848.750000
# Rohini            49.468000  183164.400000
# Saket             46.940000  306976.500000
# Shahdara          18.806000  291422.600000
# Shalimar Bagh     58.800000  359488.000000
# Tilak Nagar       26.735000  203079.250000
# Uttam Nagar       56.156667  196004.333333
# Vasant Kunj       47.700000  216235.500000
# Vikaspuri         32.140000   54645.000000
# Vivek Vihar       43.595000  294335.875000

# %%
df.corr(numeric_only=True)
# Out:
#                     population  avg_income  crime_rate  pollution_index  \
# population            1.000000   -0.098401    0.029180         0.058347
# avg_income           -0.098401    1.000000    0.038384        -0.129826
# crime_rate            0.029180    0.038384    1.000000        -0.024226
# pollution_index       0.058347   -0.129826   -0.024226         1.000000
# literacy_rate        -0.017178    0.016754    0.035917         0.053433
# area_sq_km            0.019624   -0.089626   -0.091324        -0.036037
# population_density    0.287217    0.024578    0.131741         0.017758
#
#                     literacy_rate  area_sq_km  population_density
# population              -0.017178    0.019624            0.287217
# avg_income               0.016754   -0.089626            0.024578
# crime_rate               0.035917   -0.091324            0.131741
# pollution_index          0.053433   -0.036037            0.017758
# literacy_rate            1.000000   -0.068175            0.017645
# area_sq_km              -0.068175    1.000000           -0.626079
# population_density       0.017645   -0.626079            1.000000

# %%
Q1 = df["population"].quantile(0.25)
Q3 = df["population"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

outliers = df[
    (df["population"] < lower_limit) |
    (df["population"] > upper_limit)
]

outliers
# Out:
# Empty DataFrame
# Columns: [area, population, avg_income, crime_rate, pollution_index, literacy_rate, area_sq_km, population_density]
# Index: []

# %%
plt.hist(df["population"], bins=10)
plt.xlabel("Population")
plt.ylabel("Number of Areas")
plt.title("Population Distribution")
plt.show()

# %%
plt.boxplot(df["population"])
plt.ylabel("Population")
plt.title("Population Distribution and Outliers")
plt.show()

# %%
df.describe()
# Out:
#           population     avg_income  crime_rate  pollution_index  \
# count     150.000000     150.000000  150.000000       150.000000
# mean   270623.333333  114465.120000   47.934733        56.863333
# std    142183.214914   51195.146755   26.506598        21.576922
# min     24462.000000   21866.000000    5.550000        20.480000
# 25%    144519.500000   75064.250000   25.197500        39.645000
# 50%    273273.500000  117916.000000   47.485000        54.295000
# 75%    387765.250000  158481.000000   72.957500        74.995000
# max    497060.000000  199131.000000   94.900000        94.880000
#
#        literacy_rate  area_sq_km  population_density
# count     150.000000  150.000000          150.000000
# mean       84.607933   16.592667        35196.267400
# std         7.974264   10.329669        48779.669385
# min        70.120000    1.020000          905.270000
# 25%        77.610000    6.905000         7239.060000
# 50%        84.860000   16.605000        16725.530000
# 75%        91.362500   26.232500        35215.347500
# max        98.980000   34.220000       282750.930000

# %%
df["population"].skew()
# Out:
# np.float64(0.003836862606173061)

# %%
df["avg_income"].skew()
# Out:
# np.float64(-0.1384573732696888)

# %%
print("Mean:", df["avg_income"].mean())
print("Median:", df["avg_income"].median())
print("Skewness:", df["avg_income"].skew())
# Out:
# Mean: 114465.12
# Median: 117916.0
# Skewness: -0.1384573732696888

# %%
df["population"].corr(df["pollution_index"])
# Out:
# np.float64(0.05834718043571934)

# %%
df.corr(numeric_only=True)
# Out:
#                     population  avg_income  crime_rate  pollution_index  \
# population            1.000000   -0.098401    0.029180         0.058347
# avg_income           -0.098401    1.000000    0.038384        -0.129826
# crime_rate            0.029180    0.038384    1.000000        -0.024226
# pollution_index       0.058347   -0.129826   -0.024226         1.000000
# literacy_rate        -0.017178    0.016754    0.035917         0.053433
# area_sq_km            0.019624   -0.089626   -0.091324        -0.036037
# population_density    0.287217    0.024578    0.131741         0.017758
#
#                     literacy_rate  area_sq_km  population_density
# population              -0.017178    0.019624            0.287217
# avg_income               0.016754   -0.089626            0.024578
# crime_rate               0.035917   -0.091324            0.131741
# pollution_index          0.053433   -0.036037            0.017758
# literacy_rate            1.000000   -0.068175            0.017645
# area_sq_km              -0.068175    1.000000           -0.626079
# population_density       0.017645   -0.626079            1.000000

# %%
df["population"].corr(df["pollution_index"])
# Out:
# np.float64(0.05834718043571934)

# %%
df.sort_values("population", ascending=False).head(1)
# Out:
#          area  population  avg_income  crime_rate  pollution_index  \
# 127  Shahdara      497060      187770       11.78            78.72
#
#      literacy_rate  area_sq_km  population_density
# 127          82.26       20.38            24389.75

# %%
df.groupby("area")["crime_rate"].mean().sort_values(ascending=False).head(5)
# Out:
# area
# Lajpat Nagar       77.460000
# Patel Nagar        75.996667
# Punjabi Bagh       75.806667
# Kamla Nagar        71.088571
# Greater Kailash    69.546667
# Name: crime_rate, dtype: float64

# %%
df.groupby("area")["avg_income"].mean().sort_values(ascending=False).head(10)
# Out:
# area
# Paschim Vihar    193901.500000
# Uttam Nagar      171248.000000
# Shalimar Bagh    167348.000000
# Saket            155623.000000
# Shahdara         150164.400000
# Karkardooma      148099.200000
# Green Park       148046.285714
# Preet Vihar      145682.000000
# Rohini           145177.800000
# Tilak Nagar      142752.750000
# Name: avg_income, dtype: float64

# %%
top_income = df.groupby("area")["avg_income"].mean().sort_values(ascending=False).head(10)
top_income.plot(kind = "bar", figsize = (10,5))
plt.title("TOP 10 AREAS BY AVERAGE INCOME ")
plt.xlabel("Area")
plt.ylabel("Average Income ")
plt.xticks(rotation = 45)
plt.show()

# %%
top_population = df.groupby("area")["population"].mean().sort_values(ascending=False).head(10)

top_population
# Out:
# area
# Punjabi Bagh      429778.000000
# Dwarka            410917.000000
# Mayur Vihar       399781.000000
# Paschim Vihar     396060.000000
# Okhla             383897.000000
# Rajouri Garden    377848.750000
# Laxmi Nagar       369056.333333
# Paharganj         362877.333333
# Shalimar Bagh     359488.000000
# Dilshad Garden    354656.166667
# Name: population, dtype: float64

# %%
top_population.plot(kind="bar", figsize=(10,5))

plt.title("Top 10 Areas by Population")
plt.xlabel("Area")
plt.ylabel("Average Population")
plt.xticks(rotation=45)
plt.show()

# %%
df[["crime_rate","avg_income"]].corr()
# Out:
#             crime_rate  avg_income
# crime_rate    1.000000    0.038384
# avg_income    0.038384    1.000000

# %%
#Average income and crime rate have almost no linear relationship in this dataset.

# %%
df[["population", "crime_rate"]].corr()
# Out:
#             population  crime_rate
# population     1.00000     0.02918
# crime_rate     0.02918     1.00000

# %%
df["crime_rate"].describe()
# Out:
# count    150.000000
# mean      47.934733
# std       26.506598
# min        5.550000
# 25%       25.197500
# 50%       47.485000
# 75%       72.957500
# max       94.900000
# Name: crime_rate, dtype: float64

# %%
df["crime_rate"].plot(kind = "hist",bins = 10 , figsize = (10,8))
plt.title("Distribution of Crime Rate")
plt.xlabel("Crime Rate ")
plt.ylabel("Frequency")
plt.show()

# %%
df["crime_rate"].plot(kind="box", figsize=(6,5))

plt.title("Crime Rate - Box Plot")
plt.ylabel("Crime Rate")
plt.show()

# %%
df["avg_income"].describe()
# Out:
# count       150.000000
# mean     114465.120000
# std       51195.146755
# min       21866.000000
# 25%       75064.250000
# 50%      117916.000000
# 75%      158481.000000
# max      199131.000000
# Name: avg_income, dtype: float64

# %%
df["avg_income"].plot(kind="hist", bins=10, figsize=(8,5))

plt.title("Distribution of Average Income")
plt.xlabel("Average Income")
plt.ylabel("Frequency")
plt.show()

# %%
df["avg_income"].plot(kind="box", figsize=(6,5))

plt.title("Average Income - Box Plot")
plt.ylabel("Average Income")
plt.show()

# %%
df["population"].describe()
# Out:
# count       150.000000
# mean     270623.333333
# std      142183.214914
# min       24462.000000
# 25%      144519.500000
# 50%      273273.500000
# 75%      387765.250000
# max      497060.000000
# Name: population, dtype: float64

# %%
df["population"].plot(kind="hist", bins=10, figsize=(8,5))

plt.title("Distribution of Population")
plt.xlabel("Population")
plt.ylabel("Frequency")
plt.show()

# %%
df["population_density"].describe()
# Out:
# count       150.000000
# mean      35196.267400
# std       48779.669385
# min         905.270000
# 25%        7239.060000
# 50%       16725.530000
# 75%       35215.347500
# max      282750.930000
# Name: population_density, dtype: float64

# %%
df["population_density"].plot(kind="hist", bins=10, figsize=(8,5))

plt.title("Distribution of Population Density")
plt.xlabel("Population Density")
plt.ylabel("Frequency")
plt.show()

# %%
df[["literacy_rate", "avg_income"]].corr()
# Out:
#                literacy_rate  avg_income
# literacy_rate       1.000000    0.016754
# avg_income          0.016754    1.000000

# %%
corr = df.select_dtypes(include="number").corr()

corr
# Out:
#                     population  avg_income  crime_rate  pollution_index  \
# population            1.000000   -0.098401    0.029180         0.058347
# avg_income           -0.098401    1.000000    0.038384        -0.129826
# crime_rate            0.029180    0.038384    1.000000        -0.024226
# pollution_index       0.058347   -0.129826   -0.024226         1.000000
# literacy_rate        -0.017178    0.016754    0.035917         0.053433
# area_sq_km            0.019624   -0.089626   -0.091324        -0.036037
# population_density    0.287217    0.024578    0.131741         0.017758
#
#                     literacy_rate  area_sq_km  population_density
# population              -0.017178    0.019624            0.287217
# avg_income               0.016754   -0.089626            0.024578
# crime_rate               0.035917   -0.091324            0.131741
# pollution_index          0.053433   -0.036037            0.017758
# literacy_rate            1.000000   -0.068175            0.017645
# area_sq_km              -0.068175    1.000000           -0.626079
# population_density       0.017645   -0.626079            1.000000

# %%
df[["pollution_index", "population_density"]].corr()
# Out:
#                     pollution_index  population_density
# pollution_index            1.000000            0.017758
# population_density         0.017758            1.000000

# %%
df["area"].nunique()
# Out:
# 38

# %%
df["area"].value_counts().head(10)
# Out:
# area
# Vivek Vihar        8
# Green Park         7
# Connaught Place    7
# Jasola             7
# Kamla Nagar        7
# Kalkaji            6
# Mukherjee Nagar    6
# Dilshad Garden     6
# Greater Kailash    6
# Karkardooma        5
# Name: count, dtype: int64

# %%
df["area"].value_counts().tail(10)
# Out:
# area
# Punjabi Bagh     3
# Laxmi Nagar      3
# Vasant Kunj      2
# Paschim Vihar    2
# Saket            2
# Karol Bagh       1
# Lajpat Nagar     1
# Vikaspuri        1
# Shalimar Bagh    1
# Okhla            1
# Name: count, dtype: int64

# %%
df["area"].value_counts().describe()
# Out:
# count    38.000000
# mean      3.947368
# std       1.944464
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       8.000000
# Name: count, dtype: float64

# %%
df.groupby("area")["population"].mean().sort_values(ascending = False).head(10)
# Out:
# area
# Punjabi Bagh      429778.000000
# Dwarka            410917.000000
# Mayur Vihar       399781.000000
# Paschim Vihar     396060.000000
# Okhla             383897.000000
# Rajouri Garden    377848.750000
# Laxmi Nagar       369056.333333
# Paharganj         362877.333333
# Shalimar Bagh     359488.000000
# Dilshad Garden    354656.166667
# Name: population, dtype: float64

# %%
df.groupby("area")["crime_rate"].mean().sort_values(ascending = False).head(10)
# Out:
# area
# Lajpat Nagar       77.460000
# Patel Nagar        75.996667
# Punjabi Bagh       75.806667
# Kamla Nagar        71.088571
# Greater Kailash    69.546667
# Laxmi Nagar        63.766667
# Dwarka             63.696667
# Paharganj          61.636667
# Preet Vihar        59.346667
# Shalimar Bagh      58.800000
# Name: crime_rate, dtype: float64

# %%
df.groupby("area")["avg_income"].mean().sort_values(ascending = False).head(10)
# Out:
# area
# Paschim Vihar    193901.500000
# Uttam Nagar      171248.000000
# Shalimar Bagh    167348.000000
# Saket            155623.000000
# Shahdara         150164.400000
# Karkardooma      148099.200000
# Green Park       148046.285714
# Preet Vihar      145682.000000
# Rohini           145177.800000
# Tilak Nagar      142752.750000
# Name: avg_income, dtype: float64

# %%
df.groupby("area")["literacy_rate"].mean().sort_values(ascending=False).head(10)
# Out:
# area
# Lajpat Nagar      96.060000
# Kalkaji           93.345000
# Preet Vihar       92.450000
# Janakpuri         91.626667
# Paharganj         89.493333
# Vasant Kunj       88.895000
# Jasola            88.601429
# Laxmi Nagar       88.560000
# Saket             88.465000
# Dilshad Garden    87.723333
# Name: literacy_rate, dtype: float64

# %%
df.groupby("area")["pollution_index"].mean().sort_values(ascending=False).head(10)
# Out:
# area
# Vasant Kunj      87.440000
# Karol Bagh       78.100000
# Paharganj        75.866667
# Shalimar Bagh    75.810000
# Patel Nagar      75.363333
# Uttam Nagar      73.723333
# Janakpuri        73.623333
# Paschim Vihar    72.755000
# Civil Lines      72.022500
# Pitampura        70.966667
# Name: pollution_index, dtype: float64

# %%
area_summary = df.groupby("area")[[
    "population",
    "avg_income",
    "crime_rate",
    "pollution_index"
]].mean()

area_summary
# Out:
#                     population     avg_income  crime_rate  pollution_index
# area
# Chandni Chowk    158046.200000   90853.800000   50.662000        47.378000
# Civil Lines      162535.500000   79845.500000   26.457500        72.022500
# Connaught Place  215351.428571   91899.000000   31.354286        54.197143
# Dilshad Garden   354656.166667   86736.000000   40.556667        46.045000
# Dwarka           410917.000000  128578.000000   63.696667        62.280000
# Greater Kailash  287164.500000  122758.333333   69.546667        53.706667
# Green Park       276742.142857  148046.285714   35.161429        57.400000
# Hauz Khas        244451.750000   79080.500000   42.822500        65.035000
# Janakpuri        320895.000000   90437.666667   42.256667        73.623333
# Jasola           250851.428571  118539.714286   54.410000        57.504286
# Kalkaji          267657.000000   79079.833333   47.505000        52.478333
# Kamla Nagar      166050.857143   94437.714286   71.088571        47.241429
# Karkardooma      336938.000000  148099.200000   38.332000        65.320000
# Karol Bagh       197199.000000  120952.000000   34.620000        78.100000
# Lajpat Nagar      24462.000000  127512.000000   77.460000        67.430000
# Laxmi Nagar      369056.333333  105007.666667   63.766667        64.040000
# Malviya Nagar    347394.000000   94352.666667   36.590000        34.866667
# Mayur Vihar      399781.000000  109297.200000   56.338000        52.546000
# Model Town       258062.000000   67886.250000   39.285000        49.215000
# Mukherjee Nagar  251587.666667  107631.333333   40.455000        48.726667
# Okhla            383897.000000   23685.000000   56.770000        42.280000
# Paharganj        362877.333333  103235.666667   61.636667        75.866667
# Paschim Vihar    396060.000000  193901.500000   54.240000        72.755000
# Patel Nagar      180845.333333  105418.666667   75.996667        75.363333
# Pitampura        189095.000000  141253.666667   46.720000        70.966667
# Preet Vihar      271773.666667  145682.000000   59.346667        41.286667
# Punjabi Bagh     429778.000000   63234.333333   75.806667        70.213333
# Rajendra Place   246159.250000  126941.000000   51.552500        53.027500
# Rajouri Garden   377848.750000  140394.000000   47.515000        36.185000
# Rohini           183164.400000  145177.800000   49.468000        53.302000
# Saket            306976.500000  155623.000000   46.940000        38.370000
# Shahdara         291422.600000  150164.400000   18.806000        53.532000
# Shalimar Bagh    359488.000000  167348.000000   58.800000        75.810000
# Tilak Nagar      203079.250000  142752.750000   26.735000        55.547500
# Uttam Nagar      196004.333333  171248.000000   56.156667        73.723333
# Vasant Kunj      216235.500000  138261.500000   47.700000        87.440000
# Vikaspuri         54645.000000  107966.000000   32.140000        25.240000
# Vivek Vihar      294335.875000  111016.750000   43.595000        64.020000

# %%
area_summary.sort_values("avg_income", ascending=False).head(10)
# Out:
#                   population     avg_income  crime_rate  pollution_index
# area
# Paschim Vihar  396060.000000  193901.500000   54.240000        72.755000
# Uttam Nagar    196004.333333  171248.000000   56.156667        73.723333
# Shalimar Bagh  359488.000000  167348.000000   58.800000        75.810000
# Saket          306976.500000  155623.000000   46.940000        38.370000
# Shahdara       291422.600000  150164.400000   18.806000        53.532000
# Karkardooma    336938.000000  148099.200000   38.332000        65.320000
# Green Park     276742.142857  148046.285714   35.161429        57.400000
# Preet Vihar    271773.666667  145682.000000   59.346667        41.286667
# Rohini         183164.400000  145177.800000   49.468000        53.302000
# Tilak Nagar    203079.250000  142752.750000   26.735000        55.547500

# %%
df.groupby("area")["population_density"].mean().sort_values(ascending=False).head(10)
# Out:
# area
# Model Town         100145.022500
# Malviya Nagar       86977.620000
# Laxmi Nagar         82001.820000
# Greater Kailash     70530.435000
# Karkardooma         68016.202000
# Uttam Nagar         62922.630000
# Shalimar Bagh       58212.640000
# Paschim Vihar       57312.715000
# Mayur Vihar         55368.738000
# Dilshad Garden      48490.816667
# Name: population_density, dtype: float64

# %%
area_summary.query("avg_income > 100000 and crime_rate < 50")
# Out:
#                     population     avg_income  crime_rate  pollution_index
# area
# Green Park       276742.142857  148046.285714   35.161429        57.400000
# Karkardooma      336938.000000  148099.200000   38.332000        65.320000
# Karol Bagh       197199.000000  120952.000000   34.620000        78.100000
# Mukherjee Nagar  251587.666667  107631.333333   40.455000        48.726667
# Pitampura        189095.000000  141253.666667   46.720000        70.966667
# Rajouri Garden   377848.750000  140394.000000   47.515000        36.185000
# Rohini           183164.400000  145177.800000   49.468000        53.302000
# Saket            306976.500000  155623.000000   46.940000        38.370000
# Shahdara         291422.600000  150164.400000   18.806000        53.532000
# Tilak Nagar      203079.250000  142752.750000   26.735000        55.547500
# Vasant Kunj      216235.500000  138261.500000   47.700000        87.440000
# Vikaspuri         54645.000000  107966.000000   32.140000        25.240000
# Vivek Vihar      294335.875000  111016.750000   43.595000        64.020000

# %%
print("Highest Income Area:", area_summary["avg_income"].idxmax())
print("Lowest Crime Area:", area_summary["crime_rate"].idxmin())
# Out:
# Highest Income Area: Paschim Vihar
# Lowest Crime Area: Shahdara

# %%
area_summary = area_summary.reset_index()

# %%
area_summary.head()
# Out:
#               area     population  avg_income  crime_rate  pollution_index
# 0    Chandni Chowk  158046.200000     90853.8   50.662000        47.378000
# 1      Civil Lines  162535.500000     79845.5   26.457500        72.022500
# 2  Connaught Place  215351.428571     91899.0   31.354286        54.197143
# 3   Dilshad Garden  354656.166667     86736.0   40.556667        46.045000
# 4           Dwarka  410917.000000    128578.0   63.696667        62.280000

# %%
area_summary["income_category"] = pd.cut(
    area_summary["avg_income"],
    bins = [0,75000,125000,float("inf")],
    labels = ["low","medium","high"]
)
area_summary[["area","avg_income","income_category"]]
# Out:
#                area     avg_income income_category
# 0     Chandni Chowk   90853.800000          medium
# 1       Civil Lines   79845.500000          medium
# 2   Connaught Place   91899.000000          medium
# 3    Dilshad Garden   86736.000000          medium
# 4            Dwarka  128578.000000            high
# 5   Greater Kailash  122758.333333          medium
# 6        Green Park  148046.285714            high
# 7         Hauz Khas   79080.500000          medium
# 8         Janakpuri   90437.666667          medium
# 9            Jasola  118539.714286          medium
# 10          Kalkaji   79079.833333          medium
# 11      Kamla Nagar   94437.714286          medium
# 12      Karkardooma  148099.200000            high
# 13       Karol Bagh  120952.000000          medium
# 14     Lajpat Nagar  127512.000000            high
# 15      Laxmi Nagar  105007.666667          medium
# 16    Malviya Nagar   94352.666667          medium
# 17      Mayur Vihar  109297.200000          medium
# 18       Model Town   67886.250000             low
# 19  Mukherjee Nagar  107631.333333          medium
# 20            Okhla   23685.000000             low
# 21        Paharganj  103235.666667          medium
# 22    Paschim Vihar  193901.500000            high
# 23      Patel Nagar  105418.666667          medium
# 24        Pitampura  141253.666667            high
# 25      Preet Vihar  145682.000000            high
# 26     Punjabi Bagh   63234.333333             low
# 27   Rajendra Place  126941.000000            high
# 28   Rajouri Garden  140394.000000            high
# 29           Rohini  145177.800000            high
# 30            Saket  155623.000000            high
# 31         Shahdara  150164.400000            high
# 32    Shalimar Bagh  167348.000000            high
# 33      Tilak Nagar  142752.750000            high
# 34      Uttam Nagar  171248.000000            high
# 35      Vasant Kunj  138261.500000            high
# 36        Vikaspuri  107966.000000          medium
# 37      Vivek Vihar  111016.750000          medium

# %%
area_summary["income_category"].value_counts()
# Out:
# income_category
# medium    19
# high      16
# low        3
# Name: count, dtype: int64

# %%
area_summary.groupby("income_category",observed  = True)["crime_rate"].mean()
# Out:
# income_category
# low       57.287222
# medium    48.515677
# high      48.664371
# Name: crime_rate, dtype: float64

# %%
income_vs_crime = area_summary.groupby("income_category",observed  = True)["crime_rate"].mean()

# %%
income_vs_crime.plot(kind = "bar")
plt.title("Average Crime Rate by Income Category")
plt.xlabel("Income Category")
plt.ylabel("Crime Rate")
plt.show()

# %%
income_vs_pollution =  area_summary.groupby("income_category",observed = True)["pollution_index"].mean()

# %%
income_vs_pollution.plot(kind = "bar")
plt.title("Average Pollution Index BY Income Category")
plt.xlabel("Income category")
plt.ylabel("Average Pollution Index ")
plt.show()

# %%
income_vs_population = area_summary.groupby("income_category",observed = True)["population"].mean()

# %%
income_vs_population.plot(kind ="bar")
plt.title("Average Population By Income category")
plt.xlabel("Income Category")
plt.ylabel("Average population")
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
area_summary[["population","crime_rate"]].corr()

# %%
plt.scatter(area_summary["population"], area_summary["crime_rate"])

plt.title("Population vs Crime Rate")
plt.xlabel("Population")
plt.ylabel("Crime Rate")
plt.show()

# %%
top_crime_area = area_summary.sort_values("crime_rate",ascending = False)
top_crime_area[["area","crime_rate"]].head(10)

# %%
bottom_crime_areas = area_summary.sort_values("crime_rate",ascending = True)
bottom_crime_areas[["area","crime_rate"]].head(10)

# %%
area_summary["crime_rate"].describe()

# %%
plt.hist(area_summary["crime_rate"], bins=8)

plt.title("Distribution of Crime Rate")
plt.xlabel("Crime Rate")
plt.ylabel("Number of Areas")
plt.show()

# %%
Q1 = area_summary["crime_rate"].quantile(0.25)
Q3 = area_summary["crime_rate"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)

# %%
outliers = area_summary[
    (area_summary["crime_rate"] < lower_limit) |
    (area_summary["crime_rate"] > upper_limit)
]

outliers[["area", "crime_rate"]]

# %%
crime_without_okhla = area_summary[
    area_summary["area"] != "Okhla"
]["crime_rate"].mean()

print("Overall Mean Crime Rate:", area_summary["crime_rate"].mean())
print("Mean Without Okhla:", crime_without_okhla)

# %%
def classify_crime(rate):
    if rate <= Q1:
        return "Low"
    elif rate <= Q3:
        return "Medium"
    else:
        return "High"

area_summary["crime_category"] = area_summary["crime_rate"].apply(classify_crime)

area_summary[["area", "crime_rate", "crime_category"]]

# %%
area_summary["crime_category"].value_counts()

# %%
area_summary.sort_values(by = ["crime_category","crime_rate"],ascending = [True,False])[["area","crime_rate","crime_category"]]

# %%
area_summary.groupby("crime_category")["crime_rate"].mean()

# %%
area_summary["crime_category"].value_counts().plot(
    kind="bar",
    title="Number of Areas by Crime Category",
    xlabel="Crime Category",
    ylabel="Number of Areas"
)

# %%
high_crime = area_summary[
    area_summary["crime_category"] == "High"
    ]
high_crime[["area","crime_rate"]].sort_values(
    by="crime_rate",
    ascending = False
)

# %%
category_percentage = (
    area_summary["crime_category"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

category_percentage

# %%
category_percentage.plot(kind = "bar")
plt.title("Crime Category Percentage")
plt.xlabel("Crime Category ")
plt.ylabel("percentage OF Area")
plt.show()

# %%
area_summary[["population","crime_rate"]].corr()

# %%
area_summary = area_summary.merge(
    df[["area", "population_density"]].drop_duplicates("area"),
    on="area",
    how="left"
)

# %%
area_summary[["population_density", "crime_rate"]].corr()

# %%
area_summary[["avg_income", "crime_rate"]].corr()

# %%
area_summary[["pollution_index", "crime_rate"]].corr()

# %%
area_summary.plot(
    kind="scatter",
    x="avg_income",
    y="crime_rate",
    title="Average Income vs Crime Rate"
)

# %%
area_summary.plot(
    kind="scatter",
    x="population_density",
    y="crime_rate",
    title="Population Density vs Crime Rate"
)

# %%
area_summary.plot(
    kind="scatter",
    x="pollution_index",
    y="crime_rate",
    title="Pollution Index vs Crime Rate"
)

# %%
area_summary[
    ["population", "avg_income", "crime_rate", "pollution_index", "population_density"]
].corr()

# %%
import matplotlib.pyplot as plt

corr = area_summary[
    ["population", "avg_income", "crime_rate",
     "pollution_index", "population_density"]
].corr()

plt.figure(figsize=(8, 6))
plt.imshow(corr, cmap="coolwarm", interpolation="nearest")
plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
area_summary[
    ["population", "avg_income", "crime_rate",
     "pollution_index", "population_density"]
].describe()

# %%
area_summary["crime_normalized"] = (
    (area_summary["crime_rate"] - area_summary["crime_rate"].min())
    /
    (area_summary["crime_rate"].max() - area_summary["crime_rate"].min())
)

# %%
area_summary["crime_normalized"].describe()

# %%
area_summary["pollution_normalized"] = (
    (area_summary["pollution_index"] - area_summary["pollution_index"].min())
    /
    (area_summary["pollution_index"].max() - area_summary["pollution_index"].min())
)

# %%
area_summary["population_normalized"] = (
    (area_summary["population"] - area_summary["population"].min())
    /
    (area_summary["population"].max() - area_summary["population"].min())
)

# %%
area_summary[
    ["area", "crime_normalized", "pollution_normalized", "population_normalized"]
].sort_values("crime_normalized", ascending=False).head(10)

# %%
area_summary.nlargest(5, "crime_rate")[
    ["area", "crime_rate"]
]

# %%
area_summary.nsmallest(5, "crime_rate")[
    ["area", "crime_rate"]
]

# %%
area_summary.nlargest(5, "pollution_index")[
    ["area", "pollution_index"]
]

# %%
area_summary.nsmallest(5,"pollution_index")[["area","pollution_index"]]

# %%
area_summary.nlargest(5,"avg_income")[["area","avg_income"]]

# %%
area_summary.nsmallest(5,"avg_income")[["area","avg_income"]]

# %%
area_summary["crime_rank"] = (
    area_summary["crime_rate"]
    .rank(method="dense", ascending=False)
    .astype(int)
)

area_summary[
    ["crime_rank", "area", "crime_rate"]
].sort_values("crime_rank").head(10)

# %%
pollution_Q1 = area_summary["pollution_index"].quantile(0.25)
pollution_Q3 = area_summary["pollution_index"].quantile(0.75)

def classify_pollution(index):
    if index <= pollution_Q1:
        return "Low"
    elif index <= pollution_Q3:
        return "Medium"
    else:
        return "High"

area_summary["pollution_category"] = (
    area_summary["pollution_index"].apply(classify_pollution)
)

area_summary[["area", "pollution_index", "pollution_category"]]

# %%
pollution_crime = (
    area_summary.groupby("pollution_category")["crime_rate"]
    .mean()
    .sort_values(ascending=False)
)

pollution_crime

# %%
pollution_crime.plot(
    kind="bar",
    title="Average Crime Rate by Pollution Category",
    xlabel="Pollution Category",
    ylabel="Average Crime Rate"
)

# %%
area_summary["pollution_category"].value_counts()

# %%
area_summary.nlargest(5, "population_density")[
    ["area", "population_density"]
]

# %%
area_summary.nsmallest(5, "population_density")[
    ["area", "population_density"]
]

# %%
top_crime_areas = area_summary.nlargest(5, "crime_rate")

top_crime_areas[
    ["area", "crime_rate", "pollution_index"]
]

# %%
top_crime_areas.set_index("area")[
    ["crime_rate", "pollution_index"]
].plot(
    kind="bar",
    title="Top 5 Crime Areas: Crime vs Pollution",
    xlabel="Area",
    ylabel="Value"
)

# %% [markdown]
# ## Key Findings
#
# 1. Civil Lines has the highest average crime rate among the analyzed areas.
# 2. Preet Vihar has the lowest average crime rate.
# 3. Most analyzed areas fall under the Medium crime category.
# 4. The correlation between average income and crime rate is almost zero, indicating no meaningful linear relationship in this dataset.
# 5. Population density also shows only a weak relationship with crime rate.
# 6. Pollution index has a weak negative correlation with crime rate; therefore, higher pollution does not necessarily mean higher crime in this dataset.
# 7. High-income areas have a higher average crime rate than medium- and low-income areas, but this comparison does not establish causation.
# 8. Overall, no single numerical factor strongly explains the variation in crime rate across the analyzed Delhi areas.

# %% [markdown]
# ## Conclusion
#
# This project analyzed different areas of Delhi using population, average income, crime rate, pollution index, and population density.
#
# The analysis shows that crime rate varies considerably across different areas. However, the correlation analysis indicates that no single factor among income, population, pollution, or population density has a strong linear relationship with crime rate in this dataset.
#
# The project demonstrates how Python, NumPy, Pandas, and Matplotlib can be used to clean, analyze, visualize, and extract meaningful insights from real-world style data.
#
# Overall, the analysis provides a data-driven overview of Delhi's area-wise characteristics and highlights that crime patterns are influenced by multiple factors rather than one simple variable.

# %% [markdown]
# ## 📊 Project Summary
#
# ### Tools & Technologies
# - Python
# - NumPy
# - Pandas
# - Matplotlib
# - JupyterLab
#
# ### Analysis Performed
# - Data cleaning and validation
# - Area-wise aggregation
# - Descriptive statistics
# - Crime categorization using IQR
# - Income and pollution categorization
# - Correlation analysis
# - Data normalization
# - Comparative analysis
# - Data visualization
#
# ### Key Takeaway
#
# The analysis shows that crime patterns vary significantly across Delhi areas, but no single analyzed variable strongly explains these differences. This highlights the importance of examining multiple factors when performing real-world data analysis.
